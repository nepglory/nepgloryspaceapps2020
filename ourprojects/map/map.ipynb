# %%
import requests
import json
from scipy.interpolate import interp1d
import pandas as pd
import numpy as np
import plotly.express as px
data = pd.read_excel('result.xls')
list1=data.Countries__TotalConfirmed.values.tolist()
m = interp1d([1,max(list1)],[3,30])
circle_radius=m(list1)

print('Carto-darkmatter')
fig=px.density_mapbox(data,lat='Countries_lat',lon='Countries_long',radius=circle_radius,zoom=0,mapbox_style='carto-darkmatter')
fig
# Out:
# Carto-darkmatter
# <div>
#
#
#             <div id="1e6b731d-722e-40ed-9d40-3304c98cf47e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e6b731d-722e-40ed-9d40-3304c98cf47e")) {
#                     Plotly.newPlot(
#                         '1e6b731d-722e-40ed-9d40-3304c98cf47e',
# ...
